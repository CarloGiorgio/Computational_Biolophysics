# %% [markdown]
# <a href="https://colab.research.google.com/github/CarloGiorgio/Computational_Biolophysics/blob/main/Clustering/Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clustering
# We try to apply the clustering tecnique analyzed during the lectures to the Iris dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN 
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve
from sklearn.metrics import adjusted_rand_score

# %%
print(load_iris.__doc__)
# Out:
# Load and return the iris dataset (classification).
#
#     The iris dataset is a classic and very easy multi-class classification
#     dataset.
#
#     =================   ==============
#     Classes                          3
#     Samples per class               50
#     Samples total                  150
#     Dimensionality                   4
#     Features            real, positive
#     =================   ==============
#
#     Read more in the :ref:`User Guide <iris_dataset>`.
#
#     Parameters
#     ----------
#     return_X_y : boolean, default=False.
#         If True, returns ``(data, target)`` instead of a Bunch object. See
#         below for more information about the `data` and `target` object.
#
#         .. versionadded:: 0.18
#
#     Returns
#     -------
#     data : Bunch
#         Dictionary-like object, the interesting attributes are:
#         'data', the data to learn, 'target', the classification labels,
# ...

# %%
(x,y)=load_iris(True)
print(x.shape,y.shape)
# Out:
# (150, 4) (150,)

# %%
fig,ax=plt.subplots()
ax.scatter(x[:,0],x[:,2],c=y)

# %% [markdown]
# ## Kmeans

# %%
km=KMeans(3,verbose=0).fit(x)
label_k=km.predict(x)
print(adjusted_rand_score(label,label_k))
# Out:
# 0.22656878632952096

# %%
km.cluster_centers_
# Out:
# array([[5.9016129 , 2.7483871 , 4.39354839, 1.43387097],
#        [5.006     , 3.428     , 1.462     , 0.246     ],
#        [6.85      , 3.07368421, 5.74210526, 2.07105263]])

# %%
plt.scatter(x[:,0],x[:,2],c=label_k)

# %%
db=DBSCAN(0.3,metric='').fit(x)
label_db=db.labels_
plt.scatter(x[:,0],x[:,2],c=label_db)
